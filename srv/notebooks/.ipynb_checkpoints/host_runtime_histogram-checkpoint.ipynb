# %%
import json
import requests
import pandas as pd

# %%
FASTAPI = 'http://172.27.0.12:8080'
TABLES_URL = FASTAPI + '/api/tower-analytics/v1/tables'
SQL_URL = FASTAPI + '/api/tower-analytics/v1/sql'

# %%
rr = requests.get(TABLES_URL)
tables = rr.json()

# %%
print(json.dumps(sorted(set([x['table'] for x in tables])), indent=2))
# Out:
# [
#   "cluster",
#   "cluster_info",
#   "cluster_system",
#   "daily_event_explorer_rollup",
#   "daily_job_explorer_rollup",
#   "daily_job_failed_step_rollup",
#   "daily_unique_hosts_rollup",
#   "deprecations",
#   "event_explorer_rollup",
#   "host",
#   "host_event_explorer_rollup",
#   "host_explorer_rollup",
#   "job",
#   "job_events_fk",
#   "job_explorer_rollup",
#   "job_failed_step_rollup",
#   "migrations",
#   "monthly_job_explorer_rollup",
#   "notification",
#   "notification_arg",
#   "notification_code",
#   "notification_severity",
#   "notification_type",
#   "organization",
#   "play",
#   "playbook",
#   "role",
#   "rollup_jobs",
#   "system",
#   "system_info",
#   "task",
#   "task_action",
#   "unified_jobs_fk",
#   "warnings",
#   "workflow_job_nodes",
#   "yearly_job_explorer_rollup"
# ]

# %%
rr = requests.post(SQL_URL, json={'query': 'select * from cluster'})
print(json.dumps(rr.json(), indent=2))
# Out:
# [
#   {
#     "cluster_id": 1,
#     "install_uuid": "ba8dbb23-c19d-4aef-a668-c971f4170b43",
#     "url_base": "https://ec2-52-90-106-58.compute-1.amazonaws.com",
#     "label": "ec2-52-90-106-58.compute-1.amazonaws.com"
#   },
#   {
#     "cluster_id": 2,
#     "install_uuid": "018dbb23-c19d-4aef-a668-c971f4170b43",
#     "url_base": "https://ec2-52-90-106-01.compute-1.amazonaws.com",
#     "label": "ec2-52-90-106-01.compute-1.amazonaws.com"
#   },
#   {
#     "cluster_id": 3,
#     "install_uuid": "108dbb23-c19d-4aef-a668-c971f4170b43",
#     "url_base": "https://ec2-52-90-106-02.compute-1.amazonaws.com",
#     "label": "ec2-52-90-106-02.compute-1.amazonaws.com"
#   },
#   {
#     "cluster_id": 4,
#     "install_uuid": "c3256bdf-d5c7-421b-9882-f728c2ea8e23",
#     "url_base": "https://192.168.122.85",
#     "label": "192.168.122.85"
#   }
# ]

# %%
#print([json.dumps(x, indent=2) for x in tables if x['table'] == 'job_events_fk'])
sql = 'select DISTINCT(host_name) from job_events_fk where cluster_id=4'
#sql = 'select DISTINCT(host_name) from job_events_fk'
rr = requests.post(SQL_URL, json={'query': sql})
hostnames = [x['host_name'] for x in rr.json()]
print(json.dumps(hostnames[:10], indent=2))
# Out:
# [
#   null,
#   2080,
#   2038,
#   2054,
#   2099,
#   2098,
#   2073,
#   2060,
#   2105,
#   2114
# ]

# %%
host_sums = []
for hn in hostnames:
    if not hn:
        continue
    sql = f"SELECT SUM(duration) FROM job_events_fk WHERE host_name='{hn}' AND duration > 0 limit 1"
    print(sql)
    try:
        rr = requests.post(SQL_URL, json={'query': sql})
        #print(rr.reason)
        #print(json.dumps(rr.json(), indent=2))
        host_sums.append({'host_name': hn, 'duration': rr.json()[0]['sum']})
    except Exception as e:
        pass
print(json.dumps(host_sums, indent=2))
# Out:
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2080' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2038' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2054' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2099' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2098' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2073' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2060' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2105' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2114' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2089' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2074' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2078' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2027' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2067' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2024' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2050' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2051' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2069' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2110' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2021' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2075' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2055' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2065' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2068' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2028' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2023' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2092' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2058' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2091' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2083' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2095' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2022' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2077' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2062' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2047' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2104' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2026' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2041' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2107' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2102' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2113' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2016' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2111' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2039' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2108' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2040' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2025' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2082' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2057' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2063' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2116' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2035' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2109' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2096' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2093' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2087' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2049' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2037' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2053' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2018' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2034' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2032' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2036' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2076' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2097' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2064' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2090' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2103' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2042' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2046' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2031' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2094' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2115' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2071' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2059' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2045' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2044' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2101' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2106' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2017' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2043' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2061' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2029' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2085' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2084' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2066' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2086' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2072' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2100' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2112' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2079' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2030' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2019' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2081' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2088' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2056' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2020' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2070' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2048' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2052' AND duration > 0 limit 1
# SELECT SUM(duration) FROM job_events_fk WHERE host_name='2033' AND duration > 0 limit 1
# [
#   {
#     "host_name": 2080,
#     "duration": 6.004704
#   },
#   {
#     "host_name": 2038,
#     "duration": 8.557242
#   },
#   {
#     "host_name": 2054,
#     "duration": 10.487697
#   },
#   {
#     "host_name": 2099,
#     "duration": 8.93053
#   },
#   {
#     "host_name": 2098,
#     "duration": 11.149925
#   },
#   {
#     "host_name": 2073,
#     "duration": 6.654027
#   },
#   {
#     "host_name": 2060,
#     "duration": 13.167142
#   },
#   {
#     "host_name": 2105,
#     "duration": 11.569562
#   },
#   {
#     "host_name": 2114,
#     "duration": 5.889907
#   },
#   {
#     "host_name": 2089,
#     "duration": 13.449423
#   },
#   {
#     "host_name": 2074,
#     "duration": 14.015529
#   },
#   {
#     "host_name": 2078,
#     "duration": 13.56526
#   },
#   {
#     "host_name": 2027,
#     "duration": 11.938951
#   },
#   {
#     "host_name": 2067,
#     "duration": 6.035516
#   },
#   {
#     "host_name": 2024,
#     "duration": 12.809872
#   },
#   {
#     "host_name": 2050,
#     "duration": 8.538121
#   },
#   {
#     "host_name": 2051,
#     "duration": 11.485572
#   },
#   {
#     "host_name": 2069,
#     "duration": 4.578695
#   },
#   {
#     "host_name": 2110,
#     "duration": 4.886142
#   },
#   {
#     "host_name": 2021,
#     "duration": 27.442985
#   },
#   {
#     "host_name": 2075,
#     "duration": 12.559957
#   },
#   {
#     "host_name": 2055,
#     "duration": 4.462849
#   },
#   {
#     "host_name": 2065,
#     "duration": 9.13471
#   },
#   {
#     "host_name": 2068,
#     "duration": 9.31307
#   },
#   {
#     "host_name": 2028,
#     "duration": 12.422022
#   },
#   {
#     "host_name": 2023,
#     "duration": 9.723879
#   },
#   {
#     "host_name": 2092,
#     "duration": 8.958992
#   },
#   {
#     "host_name": 2058,
#     "duration": 12.911042
#   },
#   {
#     "host_name": 2091,
#     "duration": 4.502508
#   },
#   {
#     "host_name": 2083,
#     "duration": 12.500062
#   },
#   {
#     "host_name": 2095,
#     "duration": 8.474019
#   },
#   {
#     "host_name": 2022,
#     "duration": 12.009114
#   },
#   {
#     "host_name": 2077,
#     "duration": 4.515651
#   },
#   {
#     "host_name": 2062,
#     "duration": 13.992734
#   },
#   {
#     "host_name": 2047,
#     "duration": 11.94363
#   },
#   {
#     "host_name": 2104,
#     "duration": 6.690428
#   },
#   {
#     "host_name": 2026,
#     "duration": 8.909139
#   },
#   {
#     "host_name": 2041,
#     "duration": 10.567363
#   },
#   {
#     "host_name": 2107,
#     "duration": 5.164987
#   },
#   {
#     "host_name": 2102,
#     "duration": 7.103917
#   },
#   {
#     "host_name": 2113,
#     "duration": 13.60205
#   },
#   {
#     "host_name": 2016,
#     "duration": 7.648174
#   },
#   {
#     "host_name": 2111,
#     "duration": 11.75398
#   },
#   {
#     "host_name": 2039,
#     "duration": 9.671766
#   },
#   {
#     "host_name": 2108,
#     "duration": 5.429178
#   },
#   {
#     "host_name": 2040,
#     "duration": 5.156652
#   },
#   {
#     "host_name": 2025,
#     "duration": 6.325616
#   },
#   {
#     "host_name": 2082,
#     "duration": 6.793139
#   },
#   {
#     "host_name": 2057,
#     "duration": 13.652778
#   },
#   {
#     "host_name": 2063,
#     "duration": 12.811606
#   },
#   {
#     "host_name": 2116,
#     "duration": 14.8859
#   },
#   {
#     "host_name": 2035,
#     "duration": 7.420811
#   },
#   {
#     "host_name": 2109,
#     "duration": 4.695766
#   },
#   {
#     "host_name": 2096,
#     "duration": 13.977316
#   },
#   {
#     "host_name": 2093,
#     "duration": 12.230631
#   },
#   {
#     "host_name": 2087,
#     "duration": 4.916973
#   },
#   {
#     "host_name": 2049,
#     "duration": 4.682802
#   },
#   {
#     "host_name": 2037,
#     "duration": 9.782542
#   },
#   {
#     "host_name": 2053,
#     "duration": 5.876136
#   },
#   {
#     "host_name": 2018,
#     "duration": 5.087892
#   },
#   {
#     "host_name": 2034,
#     "duration": 8.677995
#   },
#   {
#     "host_name": 2032,
#     "duration": 7.635427
#   },
#   {
#     "host_name": 2036,
#     "duration": 5.663947
#   },
#   {
#     "host_name": 2076,
#     "duration": 8.37387
#   },
#   {
#     "host_name": 2097,
#     "duration": 14.548847
#   },
#   {
#     "host_name": 2064,
#     "duration": 6.152898
#   },
#   {
#     "host_name": 2090,
#     "duration": 12.377193
#   },
#   {
#     "host_name": 2103,
#     "duration": 7.538592
#   },
#   {
#     "host_name": 2042,
#     "duration": 13.870422
#   },
#   {
#     "host_name": 2046,
#     "duration": 5.731773
#   },
#   {
#     "host_name": 2031,
#     "duration": 4.78178
#   },
#   {
#     "host_name": 2094,
#     "duration": 4.809899
#   },
#   {
#     "host_name": 2115,
#     "duration": 8.990157
#   },
#   {
#     "host_name": 2071,
#     "duration": 4.829447
#   },
#   {
#     "host_name": 2059,
#     "duration": 4.947003
#   },
#   {
#     "host_name": 2045,
#     "duration": 12.205437
#   },
#   {
#     "host_name": 2044,
#     "duration": 11.999465
#   },
#   {
#     "host_name": 2101,
#     "duration": 5.484038
#   },
#   {
#     "host_name": 2106,
#     "duration": 10.707596
#   },
#   {
#     "host_name": 2017,
#     "duration": 5.733409
#   },
#   {
#     "host_name": 2043,
#     "duration": 5.699309
#   },
#   {
#     "host_name": 2061,
#     "duration": 9.549379
#   },
#   {
#     "host_name": 2029,
#     "duration": 13.716035
#   },
#   {
#     "host_name": 2085,
#     "duration": 12.945079
#   },
#   {
#     "host_name": 2084,
#     "duration": 6.941838
#   },
#   {
#     "host_name": 2066,
#     "duration": 11.165419
#   },
#   {
#     "host_name": 2086,
#     "duration": 6.027244
#   },
#   {
#     "host_name": 2072,
#     "duration": 8.159195
#   },
#   {
#     "host_name": 2100,
#     "duration": 9.715077
#   },
#   {
#     "host_name": 2112,
#     "duration": 8.835996
#   },
#   {
#     "host_name": 2079,
#     "duration": 11.6428
#   },
#   {
#     "host_name": 2030,
#     "duration": 11.8115
#   },
#   {
#     "host_name": 2019,
#     "duration": 14.148053
#   },
#   {
#     "host_name": 2081,
#     "duration": 11.743772
#   },
#   {
#     "host_name": 2088,
#     "duration": 6.452137
#   },
#   {
#     "host_name": 2056,
#     "duration": 10.692379
#   },
#   {
#     "host_name": 2020,
#     "duration": 11.354662
#   },
#   {
#     "host_name": 2070,
#     "duration": 7.615373
#   },
#   {
#     "host_name": 2048,
#     "duration": 13.810135
#   },
#   {
#     "host_name": 2052,
#     "duration": 6.063649
#   },
#   {
#     "host_name": 2033,
#     "duration": 4.73302
#   }
# ]

# %%
df = pd.DataFrame.from_records(host_sums)
df.fillna(0)
# Out:
#      host_name   duration
# 0         2080   6.004704
# 1         2038   8.557242
# 2         2054  10.487697
# 3         2099   8.930530
# 4         2098  11.149925
# ..         ...        ...
# 96        2020  11.354662
# 97        2070   7.615373
# 98        2048  13.810135
# 99        2052   6.063649
# 100       2033   4.733020
#
# [101 rows x 2 columns]

# %%
df['duration'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
